# %%
###https://www.kaggle.com/royportas/movie/data

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# %matplotlib inline

# load data from cvs file and skip the first row
data = pd.read_csv('movie_metadata.csv', index_col=0)

data.columns.values
print(type(data))
print(data.shape)
print(data.columns)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (5043, 27)
# Index([u'director_name', u'num_critic_for_reviews', u'duration',
#        u'director_facebook_likes', u'actor_3_facebook_likes', u'actor_2_name',
#        u'actor_1_facebook_likes', u'gross', u'genres', u'actor_1_name',
#        u'movie_title', u'num_voted_users', u'cast_total_facebook_likes',
#        u'actor_3_name', u'facenumber_in_poster', u'plot_keywords',
#        u'movie_imdb_link', u'num_user_for_reviews', u'language', u'country',
#        u'content_rating', u'budget', u'title_year', u'actor_2_facebook_likes',
#        u'imdb_score', u'aspect_ratio', u'movie_facebook_likes'],
#       dtype='object')

# %%
# Task1: Review all features from this dataset
# Plot different features
import matplotlib.pyplot as plt

# %%
#Select the features I need to make a new dataframe
df = data[['movie_title','director_name','actor_1_name','actor_2_name','actor_3_name',
                'genres','plot_keywords','content_rating', 'genres',
           'num_critic_for_reviews',
               'duration',
               'director_facebook_likes',
               'actor_1_facebook_likes',
               'actor_2_facebook_likes',
               'actor_3_facebook_likes', 
               'gross',
               'num_voted_users',
               'cast_total_facebook_likes',
               'facenumber_in_poster',
               'num_user_for_reviews',
               'budget',
               'imdb_score',
               'movie_facebook_likes']]
plt.corrplot(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-206-ae523bd4b05f> in <module>()
#      16                'imdb_score',
#      17                'movie_facebook_likes']]
# ---> 18 plt.corrplot(df)
#
# AttributeError: 'module' object has no attribute 'corrplot'

# %%
df.plot(x = 'imdb_score', y = 'movie_facebook_likes', kind = 'scatter')
plt.xlabel('imdb score')
plt.ylabel('move facebook like')
#seaborn corrplot

# %%
df.plot(x = 'imdb_score', y = 'num_critic_for_reviews', kind = 'scatter')

# %%
df.plot(y = 'imdb_score', kind='hist')
df.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# count             5036.000000             5030.000000             5020.000000
# mean              6560.047061             1651.754473              645.009761
# std              15020.759120             4042.438863             1665.041728
# min                  0.000000                0.000000                0.000000
# 25%                614.000000              281.000000              133.000000
# 50%                988.000000              595.000000              371.500000
# 75%              11000.000000              918.000000              636.000000
# max             640000.000000           137000.000000            23000.000000
#
#               gross  num_voted_users  cast_total_facebook_likes  \
# count  4.159000e+03     5.043000e+03                5043.000000
# mean   4.846841e+07     8.366816e+04                9699.063851
# std    6.845299e+07     1.384853e+05               18163.799124
# min    1.620000e+02     5.000000e+00                   0.000000
# 25%    5.340988e+06     8.593500e+03                1411.000000
# 50%    2.551750e+07     3.435900e+04                3090.000000
# 75%    6.230944e+07     9.630900e+04               13756.500000
# max    7.605058e+08     1.689764e+06              656730.000000
#
#        facenumber_in_poster  num_user_for_reviews        budget   imdb_score  \
# count           5030.000000           5022.000000  4.551000e+03  5043.000000
# mean               1.371173            272.770808  3.975262e+07     6.442138
# std                2.013576            377.982886  2.061149e+08     1.125116
# min                0.000000              1.000000  2.180000e+02     1.600000
# 25%                0.000000             65.000000  6.000000e+06     5.800000
# 50%                1.000000            156.000000  2.000000e+07     6.600000
# 75%                2.000000            326.000000  4.500000e+07     7.200000
# max               43.000000           5060.000000  1.221550e+10     9.500000
#
#        movie_facebook_likes
# count           5043.000000
# mean            7525.964505
# std            19320.445110
# min                0.000000
# 25%                0.000000
# 50%              166.000000
# 75%             3000.000000
# max           349000.000000

# %%
#remove the line with nan information in any features
df_nonan = df.dropna()
df_nonan.info()
df_nonan.plot(x = 'imdb_score', y = 'movie_facebook_likes', kind = 'scatter')
df_nonan.plot(y = 'imdb_score', kind='hist')
#
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3807 entries, Color to Color
# Data columns (total 23 columns):
# movie_title                  3807 non-null object
# director_name                3807 non-null object
# actor_1_name                 3807 non-null object
# actor_2_name                 3807 non-null object
# actor_3_name                 3807 non-null object
# genres                       3807 non-null object
# plot_keywords                3807 non-null object
# content_rating               3807 non-null object
# genres                       3807 non-null object
# num_critic_for_reviews       3807 non-null float64
# duration                     3807 non-null float64
# director_facebook_likes      3807 non-null float64
# actor_1_facebook_likes       3807 non-null float64
# actor_2_facebook_likes       3807 non-null float64
# actor_3_facebook_likes       3807 non-null float64
# gross                        3807 non-null float64
# num_voted_users              3807 non-null int64
# cast_total_facebook_likes    3807 non-null int64
# facenumber_in_poster         3807 non-null float64
# num_user_for_reviews         3807 non-null float64
# budget                       3807 non-null float64
# imdb_score                   3807 non-null float64
# movie_facebook_likes         3807 non-null int64
# dtypes: float64(11), int64(3), object(9)
# memory usage: 713.8+ KB

# %% [raw]
# from sklearn import linear_model
# from sklearn.cross_validation import train_test_split
#
# X = df_nonan[['num_critic_for_reviews',
#                'duration',
#                'director_facebook_likes',
#                'actor_1_facebook_likes',
#                'actor_2_facebook_likes',
#                'actor_3_facebook_likes',
#                'gross',
#                'num_voted_users',
#                'cast_total_facebook_likes',
#                'facenumber_in_poster',
#                'num_user_for_reviews',
#                'budget',
#                'movie_facebook_likes']]
# y = df_nonan[['imdb_score']]

# %%
#y = np.asarray(array['imdb_score'], dtype="|S6")

# %%
# Feature Extraction with Univariate Statistical Tests (Chi-squared for classification)
import pandas
import numpy
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

array = df_nonan.values
X = array[:,9:21]
y = list(array[:,21])

# feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, y)

# summarize scores
numpy.set_printoptions(precision=3)
print(fit.scores_)
features = fit.transform(X)
# summarize selected features
print(features[0:5,:])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-201-b04256bfe6ab> in <module>()
#      11 # feature extraction
#      12 test = SelectKBest(score_func=chi2, k=4)
# ---> 13 fit = test.fit(X, y)
#      14
#      15 # summarize scores
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.pyc in fit(self, X, y)
#     329         self._check_params(X, y)
#     330
# --> 331         self.scores_, self.pvalues_ = self.score_func(X, y)
#     332         self.scores_ = np.asarray(self.scores_)
#     333         self.pvalues_ = np.asarray(self.pvalues_)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/feature_selection/univariate_selection.pyc in chi2(X, y)
#     214         raise ValueError("Input X must be non-negative.")
#     215
# --> 216     Y = LabelBinarizer().fit_transform(y)
#     217     if Y.shape[1] == 1:
#     218         Y = np.append(1 - Y, Y, axis=1)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     453         if y is None:
#     454             # fit method of arity 1 (unsupervised transformation)
# --> 455             return self.fit(X, **fit_params).transform(X)
#     456         else:
#     457             # fit method of arity 2 (supervised transformation)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.pyc in fit(self, y)
#     306
#     307         self.sparse_input_ = sp.issparse(y)
# --> 308         self.classes_ = unique_labels(y)
#     309         return self
#     310
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/utils/multiclass.pyc in unique_labels(*ys)
#      97     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#      98     if not _unique_labels:
# ---> 99         raise ValueError("Unknown label type: %s" % repr(ys))
#     100
#     101     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([ 7.9,  7.1,  6.8, ...,  6.9,  6.4,  6.6]),)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-183-660018a85ab8> in <module>()
#       1 # summarize scores
#       2 numpy.set_printoptions(precision=3)
# ----> 3 print(fit.scores_)
#       4 features = fit.transform(X)
#       5 # summarize selected features
#
# AttributeError: 'PCA' object has no attribute 'scores_'

# %%
# I am not sure which features is good for predicting a move's imdb score
# https://machinelearningmastery.com/feature-selection-machine-learning-python/
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# feature extraction
model = LogisticRegression()
rfe = RFE(model, 3)
fit = rfe.fit(X, y)
print("Num Features: %d") % fit.n_features_
print("Selected Features: %s") % fit.support_
print("Feature Ranking: %s") % fit.ranking_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-f19f99222a94> in <module>()
#       8 model = LogisticRegression()
#       9 rfe = RFE(model, 3)
# ---> 10 fit = rfe.fit(X, y)
#      11 print("Num Features: %d") % fit.n_features_
#      12 print("Selected Features: %s") % fit.support_
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/feature_selection/rfe.pyc in fit(self, X, y)
#     129             The target values.
#     130         """
# --> 131         return self._fit(X, y)
#     132
#     133     def _fit(self, X, y, step_score=None):
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/feature_selection/rfe.pyc in _fit(self, X, y, step_score)
#     172                 print("Fitting estimator with %d features." % np.sum(support_))
#     173
# --> 174             estimator.fit(X[:, features], y)
#     175
#     176             # Get coefs
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in fit(self, X, y, sample_weight)
#    1141         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
#    1142                          order="C")
# -> 1143         check_classification_targets(y)
#    1144         self.classes_ = np.unique(y)
#    1145         n_samples, n_features = X.shape
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/utils/multiclass.pyc in check_classification_targets(y)
#     171     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     172             'multilabel-indicator', 'multilabel-sequences']:
# --> 173         raise ValueError("Unknown label type: %r" % y)
#     174
#     175
#
# ValueError: Unknown label type: array([ 7.9,  7.1,  6.8, ...,  6.9,  6.4,  6.6])

# %%
import numpy
from pandas import read_csv
from sklearn.decomposition import PCA
# load data

# feature extraction
pca = PCA(n_components=3)
fit = pca.fit(X)
# summarize components
print("Explained Variance: %s") % fit.explained_variance_ratio_
print(fit.components_)
# Out:
# Explained Variance: [  9.122e-01   8.775e-02   2.518e-07]
# [[ -6.121e-08  -7.230e-09  -2.748e-07  -1.275e-06  -7.864e-07  -3.671e-07
#    -3.479e-02  -4.991e-05  -2.706e-06   1.979e-10  -1.418e-07  -9.994e-01]
#  [ -8.140e-07  -7.894e-08  -6.070e-06  -3.203e-05  -1.632e-05  -8.056e-06
#    -9.994e-01  -1.354e-03  -6.427e-05   8.219e-10  -3.190e-06   3.479e-02]
#  [  4.053e-04   4.574e-05   7.073e-03   1.571e-02   4.382e-03   1.673e-03
#    -1.356e-03   9.996e-01   2.190e-02  -2.798e-07   1.947e-03  -2.794e-06]]

# %%
from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier

#array = df_nonan.values
#X = array[:,9:22]
#y = array[:,21]
# feature extraction
model = ExtraTreesClassifier()
model.fit(X, y)
print(model.feature_importances_)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-200-fb68f60f22e1> in <module>()
#       7 # feature extraction
#       8 model = ExtraTreesClassifier()
# ----> 9 model.fit(X, y)
#      10 print(model.feature_importances_)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in fit(self, X, y, sample_weight)
#     233         self.n_outputs_ = y.shape[1]
#     234
# --> 235         y, expanded_class_weight = self._validate_y_class_weight(y)
#     236
#     237         if getattr(y, "dtype", None) != DOUBLE or not y.flags.contiguous:
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/ensemble/forest.pyc in _validate_y_class_weight(self, y)
#     419
#     420     def _validate_y_class_weight(self, y):
# --> 421         check_classification_targets(y)
#     422
#     423         y = np.copy(y)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/utils/multiclass.pyc in check_classification_targets(y)
#     171     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     172             'multilabel-indicator', 'multilabel-sequences']:
# --> 173         raise ValueError("Unknown label type: %r" % y)
#     174
#     175
#
# ValueError: Unknown label type: array([[7.9],
#        [7.1],
#        [6.8],
#        ...,
#        [6.9],
#        [6.4],
#        [6.6]], dtype=object)

# %%
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
reg =  linear_model.LinearRegression()
reg.fit(X_train, y_train)
y_pred = reg.predict(X_test)
reg.score(X_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-d02d1f7adaaf> in <module>()
#       1 X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
#       2 reg =  linear_model.LinearRegression()
# ----> 3 reg.fit(X_train, y_train)
#       4 y_pred = reg.predict(X_test)
#       5 reg.score(X_test, y_test)
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in fit(self, X, y, sample_weight)
#     425         n_jobs_ = self.n_jobs
#     426         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 427                          y_numeric=True, multi_output=True)
#     428
#     429         if ((sample_weight is not None) and np.atleast_1d(sample_weight).ndim > 1):
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     518         y = y.astype(np.float64)
#     519
# --> 520     check_consistent_length(X, y)
#     521
#     522     return X, y
#
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_consistent_length(*arrays)
#     174     if len(uniques) > 1:
#     175         raise ValueError("Found arrays with inconsistent numbers of samples: "
# --> 176                          "%s" % str(uniques))
#     177
#     178
#
# ValueError: Found arrays with inconsistent numbers of samples: [1143 2664]

# %%
data[data.director_name == 'James Cameron'][['movie_title', 'budget', 'gross']]
# Out:
#                       movie_title       budget        gross
# 0                         Avatar   237000000.0  760505847.0
# 26                       Titanic   200000000.0  658672302.0
# 288   Terminator 2: Judgment Day   102000000.0  204843350.0
# 291                    True Lies   115000000.0  146282411.0
# 606                    The Abyss    69500000.0   54222000.0
# 2486                      Aliens    18500000.0   85200000.0
# 3575              The Terminator     6500000.0   38400000.0

# %%
a = data[['movie_title','director','genres', 'plot_keywords','imdb_score', 'title_year', 'movie_imdb_likes','number_voted_users','cast_total_facebook_likes']]
a = a.set_index('movie_title')
profit = a['gross'] / a['budget']
a['profit_ratio'] = profit
a.sort('profit_ratio', ascending=False)['profit_ratio'].head(10).plot('bar')
# Out:
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:5: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """

# %%
\b = data[['movie_title','director_name','genres','plot_keywords','imdb_score','title_year','movie_imdb_link','num_voted_users','cast_total_facebook_likes']]
#data.columns.values
b['genres']
# Out:
# 0                         Action|Adventure|Fantasy|Sci-Fi
# 1                                Action|Adventure|Fantasy
# 2                               Action|Adventure|Thriller
# 3                                         Action|Thriller
# 4                                             Documentary
# 5                                 Action|Adventure|Sci-Fi
# 6                                Action|Adventure|Romance
# 7       Adventure|Animation|Comedy|Family|Fantasy|Musi...
# 8                                 Action|Adventure|Sci-Fi
# 9                        Adventure|Family|Fantasy|Mystery
# 10                                Action|Adventure|Sci-Fi
# 11                                Action|Adventure|Sci-Fi
# 12                                       Action|Adventure
# 13                               Action|Adventure|Fantasy
# 14                               Action|Adventure|Western
# 15                        Action|Adventure|Fantasy|Sci-Fi
# 16                        Action|Adventure|Family|Fantasy
# 17                                Action|Adventure|Sci-Fi
# 18                               Action|Adventure|Fantasy
# 19          Action|Adventure|Comedy|Family|Fantasy|Sci-Fi
# 20                                      Adventure|Fantasy
# 21                               Action|Adventure|Fantasy
# 22                         Action|Adventure|Drama|History
# 23                                      Adventure|Fantasy
# 24                               Adventure|Family|Fantasy
# 25                         Action|Adventure|Drama|Romance
# 26                                          Drama|Romance
# 27                                Action|Adventure|Sci-Fi
# 28                       Action|Adventure|Sci-Fi|Thriller
# 29                       Action|Adventure|Sci-Fi|Thriller
#                               ...
# 5013                                         Drama|Family
# 5014                                Action|Crime|Thriller
# 5015                                         Comedy|Drama
# 5016                                 Crime|Drama|Thriller
# 5017                                       Comedy|Romance
# 5018                                                Drama
# 5019                              Horror|Mystery|Thriller
# 5020                                Drama|Horror|Thriller
# 5021                                 Comedy|Drama|Romance
# 5022                                                Drama
# 5023                                              Romance
# 5024                                      Sci-Fi|Thriller
# 5025                                  Comedy|Crime|Horror
# 5026                                  Drama|Music|Romance
# 5027                                                Drama
# 5028                                               Horror
# 5029                        Crime|Horror|Mystery|Thriller
# 5030                                                Drama
# 5031                               Comedy|Horror|Thriller
# 5032                                          Crime|Drama
# 5033                                Drama|Sci-Fi|Thriller
# 5034                                             Thriller
# 5035                  Action|Crime|Drama|Romance|Thriller
# 5036                                          Crime|Drama
# 5037                                         Comedy|Drama
# 5038                                         Comedy|Drama
# 5039                         Crime|Drama|Mystery|Thriller
# 5040                                Drama|Horror|Thriller
# 5041                                 Comedy|Drama|Romance
# 5042                                          Documentary
# Name: genres, dtype: object

# %%
directors = data.groupby('director_name').sum()
movie_count = data.groupby('director_name').count()['color']
directors['movie_count'] = movie_count
#directors = data.groupby('director_name').sum().sort('budget', ascending=False)[['budget']]

avg_budget = directors['budget'] / directors['movie_count']
directors['avg_budget'] = avg_budget
directors.sort('avg_budget', ascending=False)[['budget', 'movie_count', 'avg_budget']]
# Out:
# /Users/yanzhu/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:8: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#                                 budget  movie_count    avg_budget
# director_name
# Charles Matthau           6.000000e+06            0           inf
# Brandon Landers           1.735000e+04            0           inf
# Jonathan Meyers           1.000000e+06            0           inf
# Dave Rodriguez            1.500000e+06            0           inf
# Richard Rich              7.000000e+06            0           inf
# Darin Scott               3.000000e+06            0           inf
# Zackary Adler             2.500000e+06            0           inf
# Tung-Shing Yee            1.500000e+07            0           inf
# Joon-ho Bong              1.225470e+10            2  6.127350e+09
# Lajos Koltai              2.500000e+09            1  2.500000e+09
# Katsuhiro Ôtomo           3.227520e+09            2  1.613760e+09
# Chan-wook Park            4.215000e+09            3  1.405000e+09
# Takao Okawara             1.000000e+09            1  1.000000e+09
# Carlos Saura              7.000000e+08            1  7.000000e+08
# Hayao Miyazaki            2.477000e+09            4  6.192500e+08
# Anurag Basu               6.000000e+08            1  6.000000e+08
# Chatrichalerm Yukol       4.000000e+08            1  4.000000e+08
# Karan Johar               7.120000e+08            2  3.560000e+08
# Tony Jaa                  3.000000e+08            1  3.000000e+08
# Nathan Greno              2.600000e+08            1  2.600000e+08
# Dan Scanlon               2.000000e+08            1  2.000000e+08
# Lee Unkrich               2.000000e+08            1  2.000000e+08
# Prachya Pinkaew           2.000000e+08            1  2.000000e+08
# David Yates               7.600000e+08            4  1.900000e+08
# Mark Andrews              1.850000e+08            1  1.850000e+08
# Joss Whedon               7.300000e+08            4  1.825000e+08
# Robert Stromberg          1.800000e+08            1  1.800000e+08
# Andrew Stanton            5.377000e+08            3  1.792333e+08
# Carl Rinsch               1.750000e+08            1  1.750000e+08
# Rupert Sanders            1.700000e+08            1  1.700000e+08
# ...                                ...          ...           ...
# Rohit Jagessar                     NaN            1           NaN
# Sajid Khan                         NaN            1           NaN
# Sammo Kam-Bo Hung                  NaN            1           NaN
# Sanaa Hamri                        NaN            2           NaN
# Sarah Gavron                       NaN            1           NaN
# Scandar Copti                      NaN            1           NaN
# Scott Smith                        NaN            1           NaN
# Sean Byrne                         NaN            1           NaN
# Sean Durkin                        NaN            1           NaN
# Shekar                             NaN            1           NaN
# Shimit Amin                        NaN            1           NaN
# Shona Auerbach                     NaN            1           NaN
# Shyam Madiraju                     NaN            1           NaN
# Simon Yin                          NaN            1           NaN
# Stacy Peralta                      NaN            2           NaN
# Stanton Barrett                    NaN            1           NaN
# Stuart Hazeldine                   NaN            1           NaN
# Tadeo Garcia                       NaN            1           NaN
# Thomas Lilti                       NaN            1           NaN
# Thorbjørn Christoffersen           NaN            1           NaN
# Tim Fywell                         NaN            1           NaN
# Travis Zariwny                     NaN            1           NaN
# Vera Farmiga                       NaN            1           NaN
# Vipul Amrutlal Shah                NaN            1           NaN
# Walter Lang                        NaN            2           NaN
# William Arntz                      NaN            1           NaN
# William Bindley                    NaN            1           NaN
# William Sachs                      NaN            1           NaN
# Yorgos Lanthimos                   NaN            1           NaN
# Zack Ward                          NaN            1           NaN
#
# [2398 rows x 3 columns]
